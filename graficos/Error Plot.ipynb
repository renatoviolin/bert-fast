# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
data = open('error2.txt', mode='r')
lines = []
for l in data:
    lin = l.replace('\n','').replace(',','.').split()
    lines.append([float(lin[3]), float(lin[7])])
lines = np.array(lines)
fig = plt.figure(figsize=(16,12))
plt.plot(lines[:,0], lines[:,1])
plt.show()

# %%
data = open('error.txt', mode='r')
lines = []
for l in data:
    lin = l.replace('\n','').replace(',','.').split()
    lines.append([float(lin[3]), float(lin[7])])
lines = np.array(lines)
fig = plt.figure(figsize=(16,12))
plt.plot(lines[:,0], lines[:,1])
plt.show()

# %%
import wikipedia
print (wikipedia.summary("In what country is Normandy located?", sentences=14))
# Out:
# Operation Overlord was the codename for the Battle of Normandy, the Allied operation that launched the successful invasion of German-occupied Western Europe during World War II. The operation was launched on 6 June 1944 with the Normandy landings (Operation Neptune, commonly known as D-Day). A 1,200-plane airborne assault preceded an amphibious assault involving more than 5,000 vessels. Nearly 160,000 troops crossed the English Channel on 6 June, and more than two million Allied troops were in France by the end of August.
# ...

# %%
import google
import urllib
from bs4 import BeautifulSoup

def google_scrape(url):
    thepage = urllib.urlopen(url)
    soup = BeautifulSoup(thepage, "html.parser")
    return soup.title.text

i = 1
query = 'search this'
for url in google.(query, stop=10):
    a = google_scrape(url)
    print (str(i) + ". " + a)
    print (url)
    print (" ")
    i += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-0ba640366738> in <module>
#      10 i = 1
#      11 query = 'search this'
# ---> 12 for url in google(query, stop=10):
#      13     a = google_scrape(url)
#      14     print (str(i) + ". " + a)
#
# TypeError: 'module' object is not callable

# %%
from google import google
num_page = 1
search_results = google.search("This is my query", num_page)
for result in search_results:
    print(result.link)
# Out:
# https://dictionary.cambridge.org/pt/dicionario/ingles/query
# https://www.linguee.com.br/ingles-portugues/traducao/queries.html
# https://downloads.mysql.com/archives/query/
# https://dev.mysql.com/doc/workbench/en/wb-sql-editor-query-panel.html
# https://www.merriam-webster.com/dictionary/query
# https://mode.com/sql-tutorial/sql-performance-tuning/
# https://mode.com/sql-tutorial/sql-select-statement/
# https://www.vertica.com/blog/need-database-query-engine/
# https://stackoverflow.com/questions/52126053/convert-query-in-my-sql-to-codeigniter-in-two-database
# https://qhelp.qqi.ie/helpdesk/

# %%
from google import google
import urllib
from bs4 import BeautifulSoup

def google_scrape(url):
    thepage = urllib.request.urlopen(url)
    soup = BeautifulSoup(thepage, "html.parser")
    return soup.title.text

i = 1
query = 'search this'
for url in google.search(query):
    a = google_scrape(url.link)
    print(str(i) + ". " + a)
    print (url)
    print (" ")

# %%
google_scrape('https://downloads.mysql.com/archives/query/')
